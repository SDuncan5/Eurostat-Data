# %%
import pandas as pd
import numpy as np
import requests
import json
import gzip
import io
import plotly.express as px

# %%
geocode_mapping = {
    "AL": "Albania",
    "AT": "Austria",
    "BE": "Belgium",
    "BG": "Bulgaria",
    "CH": "Switzerland",
    "CY": "Cyprus",
    "CZ": "Czechia",
    "DE": "Germany",
    "DK": "Denmark",
    "EA": "Euro Area",
    "EA19": "Euro Area - 2019",
    "EA20": "Euro Area - 2020",
    "EE": "Estonia",
    "EL": "Greece",
    "ES": "Spain",
    "EU": "European Union",
    "EU27_2020":"European Union 27",
    "EU28": "European Union 28",
    "FI": "Finland",
    "FR": "France",
    "HR": "Croatia",
    "HU": "Hungary",
    "IE": "Ireland",
    "IS": "Iceland",
    "IT" :"Italy",
    "LT": "Lithuania",
    "LU": "Luxembourg",
    "LV": "Latvia",
    "ME": "Montenegro",
    "MK": "North Macedonia",
    "MT": "Malta",
    "NL": "Netherlands",
    "NO": "Norway",
    "PL": "Poland",
    "PT": "Portugal",
    "RO": "Romania",
    "RS": "Serbia",
    "SE": "Sweden",
    "SI": "Slovenia",
    "SK": "Slovakia",
    "TR": "Turkey",
    "UK": "United Kingdom",
    "US": "United States",
    "XK" : "Kosovo"
}

# %% [markdown]
# # Consumer Price Index
#
# Info: https://ec.europa.eu/eurostat/cache/metadata/en/ei_cp_esms.htm
# https://ec.europa.eu/eurostat/databrowser/view/prc_hicp_aind__custom_8789219/default/table?lang=en

# %%
# df_cpi = pd.read_csv("ei_cphi_m_linear.csv")
# df_cpi

# %%
# df_cpi = pd.read_csv("https://ec.europa.eu/eurostat/api/dissemination/sdmx/2.1/data/ei_cphi_m/?format=SDMX-CSV")
# df_cpi

# %%
df_cpi_label = pd.read_csv("https://ec.europa.eu/eurostat/api/dissemination/sdmx/2.1/data/prc_hicp_aind/A.INX_A_AVG.CP00.EU+EU27_2020+EU28+EA+EA20+EA19+BE+BG+CZ+DK+DE+EE+IE+EL+ES+FR+HR+IT+CY+LV+LT+LU+HU+MT+NL+AT+PL+PT+RO+SI+SK+FI+SE+EEA+IS+NO+CH+UK+ME+MK+AL+RS+TR+XK+US/?format=SDMX-CSV&startPeriod=1996&endPeriod=2022&lang=en&label=label_only")
df_cpi_label
# Out:
#                       DATAFLOW        LAST UPDATE    freq  \
# 0     ESTAT:PRC_HICP_AIND(1.0)  17/11/23 11:00:00  Annual
# 1     ESTAT:PRC_HICP_AIND(1.0)  17/11/23 11:00:00  Annual
# 2     ESTAT:PRC_HICP_AIND(1.0)  17/11/23 11:00:00  Annual
# 3     ESTAT:PRC_HICP_AIND(1.0)  17/11/23 11:00:00  Annual
# 4     ESTAT:PRC_HICP_AIND(1.0)  17/11/23 11:00:00  Annual
# ...                        ...                ...     ...
# 1096  ESTAT:PRC_HICP_AIND(1.0)  17/11/23 11:00:00  Annual
# 1097  ESTAT:PRC_HICP_AIND(1.0)  17/11/23 11:00:00  Annual
# 1098  ESTAT:PRC_HICP_AIND(1.0)  17/11/23 11:00:00  Annual
# 1099  ESTAT:PRC_HICP_AIND(1.0)  17/11/23 11:00:00  Annual
# 1100  ESTAT:PRC_HICP_AIND(1.0)  17/11/23 11:00:00  Annual
#
#                       unit          coicop      geo  TIME_PERIOD  OBS_VALUE  \
# 0     Annual average index  All-items HICP  Albania         2016     101.51
# 1     Annual average index  All-items HICP  Albania         2017     104.76
# 2     Annual average index  All-items HICP  Albania         2018     106.59
# 3     Annual average index  All-items HICP  Albania         2019     108.39
# 4     Annual average index  All-items HICP  Albania         2020     110.74
# ...                    ...             ...      ...          ...        ...
# 1096  Annual average index  All-items HICP  Kosovo*         2018     102.84
# 1097  Annual average index  All-items HICP  Kosovo*         2019     105.59
# 1098  Annual average index  All-items HICP  Kosovo*         2020     105.80
# 1099  Annual average index  All-items HICP  Kosovo*         2021     109.35
# 1100  Annual average index  All-items HICP  Kosovo*         2022     122.01
#
#      OBS_FLAG
# 0           d
# 1           d
# 2           d
# 3           d
# 4           d
# ...       ...
# 1096        d
# 1097        d
# 1098        d
# 1099        d
# 1100        d
#
# [1101 rows x 9 columns]

# %%
# # mapping from country code to country name
# df_cpi["Country Name"] = df_cpi["geo"].map(geocode_mapping)

# %% [markdown]
# Info on the various EU values:
# https://ec.europa.eu/eurostat/statistics-explained/index.php?title=Glossary:EU_enlargements
#
# Info on the various Euro areas: https://ec.europa.eu/eurostat/statistics-explained/index.php?title=Glossary:Euro_area
#
# s_adj = seasonal adjustment. NSA = unadjusted <br>
# indic = indicator
# - CP-HI00 = HICP - All Items
# - CP-HIS = HICP - Total Services
# https://dd.eionet.europa.eu/vocabulary/eurostat/indic/view?page=9#vocabularyConceptResults

# %%
# df_cpi = df_cpi[df_cpi["indic"] == "CP-HI00"]
# df_cpi

# %%
# df_cpi = df_cpi[df_cpi["unit"] == "HICP2015"]
# # HICP = harmonized consumer price index, 2015=100
# # RT1 = Growth rate on previous period (t/t-1)
# # RT12 = Growth rate (t/t-12)
# df_cpi

# %%
# px.scatter(df_cpi, x="TIME_PERIOD", y="OBS_VALUE", color="Country Name")

# %%
df_cpi_label = pd.read_csv("https://ec.europa.eu/eurostat/api/dissemination/sdmx/2.1/data/prc_hicp_aind/A.INX_A_AVG.CP00.EU+EU27_2020+EU28+EA+EA20+EA19+BE+BG+CZ+DK+DE+EE+IE+EL+ES+FR+HR+IT+CY+LV+LT+LU+HU+MT+NL+AT+PL+PT+RO+SI+SK+FI+SE+EEA+IS+NO+CH+UK+ME+MK+AL+RS+TR+XK+US/?format=SDMX-CSV&startPeriod=1996&endPeriod=2022&lang=en&label=label_only")
df_cpi_label.rename(columns={"OBS_VALUE":"CPI"}, inplace=True)
df_cpi_label
# Out:
#                       DATAFLOW        LAST UPDATE    freq  \
# 0     ESTAT:PRC_HICP_AIND(1.0)  17/11/23 11:00:00  Annual
# 1     ESTAT:PRC_HICP_AIND(1.0)  17/11/23 11:00:00  Annual
# 2     ESTAT:PRC_HICP_AIND(1.0)  17/11/23 11:00:00  Annual
# 3     ESTAT:PRC_HICP_AIND(1.0)  17/11/23 11:00:00  Annual
# 4     ESTAT:PRC_HICP_AIND(1.0)  17/11/23 11:00:00  Annual
# ...                        ...                ...     ...
# 1096  ESTAT:PRC_HICP_AIND(1.0)  17/11/23 11:00:00  Annual
# 1097  ESTAT:PRC_HICP_AIND(1.0)  17/11/23 11:00:00  Annual
# 1098  ESTAT:PRC_HICP_AIND(1.0)  17/11/23 11:00:00  Annual
# 1099  ESTAT:PRC_HICP_AIND(1.0)  17/11/23 11:00:00  Annual
# 1100  ESTAT:PRC_HICP_AIND(1.0)  17/11/23 11:00:00  Annual
#
#                       unit          coicop      geo  TIME_PERIOD     CPI  \
# 0     Annual average index  All-items HICP  Albania         2016  101.51
# 1     Annual average index  All-items HICP  Albania         2017  104.76
# 2     Annual average index  All-items HICP  Albania         2018  106.59
# 3     Annual average index  All-items HICP  Albania         2019  108.39
# 4     Annual average index  All-items HICP  Albania         2020  110.74
# ...                    ...             ...      ...          ...     ...
# 1096  Annual average index  All-items HICP  Kosovo*         2018  102.84
# 1097  Annual average index  All-items HICP  Kosovo*         2019  105.59
# 1098  Annual average index  All-items HICP  Kosovo*         2020  105.80
# 1099  Annual average index  All-items HICP  Kosovo*         2021  109.35
# 1100  Annual average index  All-items HICP  Kosovo*         2022  122.01
#
#      OBS_FLAG
# 0           d
# 1           d
# 2           d
# 3           d
# 4           d
# ...       ...
# 1096        d
# 1097        d
# 1098        d
# 1099        d
# 1100        d
#
# [1101 rows x 9 columns]

# %%
px.scatter(df_cpi_label, x="TIME_PERIOD", y="CPI", color="geo")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e6e32950-7c0d-42eb-a66a-7bd9e8af4b3d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e6e32950-7c0d-42eb-a66a-7bd9e8af4b3d")) {                    Plotly.newPlot(                        "e6e32950-7c0d-42eb-a66a-7bd9e8af4b3d",                        [{"hovertemplate":"geo=Albania\u003cbr\u003eTIME_PERIOD=%{x}\u003cbr\u003eCPI=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Albania","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Albania","showlegend":true,"x":[2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[101.51,104.76,106.59,108.39,110.74,113.26,120.69],"yaxis":"y","type":"scattergl"},{"hovertemplate":"geo=Austria\u003cbr\u003eTIME_PERIOD=%{x}\u003cbr\u003eCPI=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Austria","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Austria","showlegend":true,"x":[1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[71.77,72.61,73.2,73.58,75.02,76.74,78.04,79.05,80.6,82.3,83.69,85.53,88.29,88.64,90.14,93.35,95.75,97.77,99.2,100.0,100.97,103.22,105.41,106.98,108.47,111.46,121.07],"yaxis":"y","type":"scattergl"},{"hovertemplate":"geo=Belgium\u003cbr\u003eTIME_PERIOD=%{x}\u003cbr\u003eCPI=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Belgium","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"Belgium","showlegend":true,"x":[1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[70.48,71.54,72.18,73.0,74.96,76.78,77.97,79.16,80.63,82.67,84.6,86.13,90.0,89.99,92.09,95.18,97.68,98.9,99.38,100.0,101.77,104.03,106.44,107.77,108.23,111.71,123.26],"yaxis":"y","type":"scattergl"},{"hovertemplate":"geo=Bulgaria\u003cbr\u003eTIME_PERIOD=%{x}\u003cbr\u003eCPI=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bulgaria","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"Bulgaria","showlegend":true,"x":[1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[40.27,47.79,49.02,54.08,58.06,61.44,62.88,66.75,70.78,76.02,81.78,91.55,93.81,96.66,99.94,102.33,102.72,101.08,100.0,98.68,99.85,102.48,104.99,106.27,109.3,123.52],"yaxis":"y","type":"scattergl"},{"hovertemplate":"geo=Switzerland\u003cbr\u003eTIME_PERIOD=%{x}\u003cbr\u003eCPI=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Switzerland","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"Switzerland","showlegend":true,"x":[2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[97.43,98.4,99.17,101.51,100.77,101.39,101.49,100.76,100.83,100.84,100.0,99.47,100.11,101.03,101.41,100.56,101.04,103.74],"yaxis":"y","type":"scattergl"},{"hovertemplate":"geo=Cyprus\u003cbr\u003eTIME_PERIOD=%{x}\u003cbr\u003eCPI=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cyprus","marker":{"color":"#19d3f3","symbol":"circle"},"mode":"markers","name":"Cyprus","showlegend":true,"x":[1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[66.81,69.02,70.63,71.44,74.91,76.4,78.53,81.65,83.2,84.88,86.79,88.67,92.55,92.71,95.09,98.4,101.45,101.84,101.57,100.0,98.78,99.45,100.23,100.78,99.67,101.92,110.17],"yaxis":"y","type":"scattergl"},{"hovertemplate":"geo=Czechia\u003cbr\u003eTIME_PERIOD=%{x}\u003cbr\u003eCPI=%{y}\u003cextra\u003e\u003c\u002fextra\u003e"," ...

# %% [markdown]
# # Immigration
# https://ec.europa.eu/eurostat/databrowser/view/migr_imm5prv/default/table?lang=en

# %%
# df_imm = pd.read_csv("https://ec.europa.eu/eurostat/api/dissemination/sdmx/2.1/data/migr_imm11prv/?format=SDMX-CSV")
# df_imm
#NR = number

#agedef
# - COMPLET: age in completed years
# - REACH: age reached during the year

# %%
# df_imm = df_imm[df_imm["agedef"] == "COMPLET"]
# df_imm["geo"].value_counts()

# %%
# df_imm["age"].value_counts()

# %%
# df_immigration = pd.read_csv("https://ec.europa.eu/eurostat/api/dissemination/sdmx/2.1/data/migr_imm5prv/A.EU28_FOR+NEU28_FOR+TOTAL+UNK+EUR+EU27_2007+EU25+EU15+BE+BG+CZ+DK+DE+EE+IE+EL+ES+FR+YT+HR+IT+CY+LV+LT+LU+HU+MT+NL+AT+PL+PT+RO+SI+SK+FI+SE+EU27_2020_FOR+EU27_2007_FOR+EFTA+IS+LI+NO+CH+EFTA_FOR+UK+CC4_10+CC3_07+BA+ME+MD+MK+AL+RS+TR+UA+XK+GE+AD+BY+GG+JE+FO+GI+VA+IM+MC+RU+SM+SJ+CZ_SK+RS_ME+EX_YU+EX_SU+EXT+HDC_EXT+MDC_EXT+LDC_EXT+NEU27_2020_FOR+NEU27_2007_FOR+EUR_OTH+AFR+AFR_C+AO+CM+CF+TD+CG+CD+GQ+GA+ST+AFR_E+BI+KM+DJ+ER+ET+KE+MG+MW+MU+MZ+RW+SC+SO+UG+TZ+ZM+ZW+AFR_N+DZ+EG+LY+MA+SS+SD+TN+EH+AFR_S+BW+LS+NA+ZA+SZ+AFR_W+BJ+BF+CV+CI+GM+GH+GN+GW+LR+ML+MR+NE+NG+SH+SN+SL+TG+AFR_OTH+AME+AME_N+BM+CA+GL+PM+US+CRB+AI+AG+AW+BS+BB+BQ+VG+KY+CU+CW+DM+DO+GD+HT+JM+MS+AN+PR+BL+KN+LC+MF+VC+SX+TT+TC+VI+AME_C+BZ+CR+SV+GT+HN+MX+NI+PA+AME_S+AR+BO+BR+CL+CO+EC+FK+GY+PY+PE+SR+UY+VE+AME_OTH+ASI+ASI_C+KZ+KG+TJ+TM+UZ+ASI_E+CN+HK+MO+JP+MN+KP+KR+TW+ASI_S+AF+BD+BT+IO+IN+IR+MV+NP+PK+LK+ASI_S_E+BN+KH+ID+LA+MY+MM+PH+SG+TH+TL+VN+ASI_W+AM+AZ+BH+IQ+IL+JO+KW+LB+PS+OM+QA+SA+SY+AE+YE+ASI_OTH+OCE+AU_NZ+AU+CX+CC+NF+NZ+MEL+FJ+NC+PG+SB+VU+MIC+GU+KI+MH+FM+NR+MP+PW+POL+AS+CK+PF+NU+PN+WS+TK+TO+TV+WF+OCE_OTH+AQ+GS+TF+RNC+OTH.COMPLET.TOTAL.NR.T.EU27_2020+BE+BG+CZ+DK+DE+EE+IE+EL+ES+FR+HR+IT+CY+LV+LT+LU+HU+MT+NL+AT+PL+PT+RO+SI+SK+FI+SE+IS+LI+NO+CH+UK+BA+ME+MD+MK+TR+UA+BY+RU+SM+KG+TJ+UZ+AM+AZ+IL/?format=SDMX-CSV&startPeriod=2010&endPeriod=2021&lang=en&label=label_only")
# df_immigration

# %%
# df_total_imm = df_immigration[df_immigration["partner"] == "Total"]
# px.scatter(df_total_imm, x="TIME_PERIOD", y="OBS_VALUE", color="geo")

# %%
df_imm_labels = pd.read_csv("https://ec.europa.eu/eurostat/api/dissemination/sdmx/2.1/data/migr_imm5prv/A.EU28_FOR+NEU28_FOR+TOTAL+UNK+EUR+EU27_2007+EU25+EU15+BE+BG+CZ+DK+DE+EE+IE+EL+ES+FR+YT+HR+IT+CY+LV+LT+LU+HU+MT+NL+AT+PL+PT+RO+SI+SK+FI+SE+EU27_2020_FOR+EU27_2007_FOR+EFTA+IS+LI+NO+CH+EFTA_FOR+UK+CC4_10+CC3_07+BA+ME+MD+MK+AL+RS+TR+UA+XK+GE+AD+BY+GG+JE+FO+GI+VA+IM+MC+RU+SM+SJ+CZ_SK+RS_ME+EX_YU+EX_SU+EXT+HDC_EXT+MDC_EXT+LDC_EXT+NEU27_2020_FOR+NEU27_2007_FOR+EUR_OTH+AFR+AFR_C+AO+CM+CF+TD+CG+CD+GQ+GA+ST+AFR_E+BI+KM+DJ+ER+ET+KE+MG+MW+MU+MZ+RW+SC+SO+UG+TZ+ZM+ZW+AFR_N+DZ+EG+LY+MA+SS+SD+TN+EH+AFR_S+BW+LS+NA+ZA+SZ+AFR_W+BJ+BF+CV+CI+GM+GH+GN+GW+LR+ML+MR+NE+NG+SH+SN+SL+TG+AFR_OTH+AME+AME_N+BM+CA+GL+PM+US+CRB+AI+AG+AW+BS+BB+BQ+VG+KY+CU+CW+DM+DO+GD+HT+JM+MS+AN+PR+BL+KN+LC+MF+VC+SX+TT+TC+VI+AME_C+BZ+CR+SV+GT+HN+MX+NI+PA+AME_S+AR+BO+BR+CL+CO+EC+FK+GY+PY+PE+SR+UY+VE+AME_OTH+ASI+ASI_C+KZ+KG+TJ+TM+UZ+ASI_E+CN+HK+MO+JP+MN+KP+KR+TW+ASI_S+AF+BD+BT+IO+IN+IR+MV+NP+PK+LK+ASI_S_E+BN+KH+ID+LA+MY+MM+PH+SG+TH+TL+VN+ASI_W+AM+AZ+BH+IQ+IL+JO+KW+LB+PS+OM+QA+SA+SY+AE+YE+ASI_OTH+OCE+AU_NZ+AU+CX+CC+NF+NZ+MEL+FJ+NC+PG+SB+VU+MIC+GU+KI+MH+FM+NR+MP+PW+POL+AS+CK+PF+NU+PN+WS+TK+TO+TV+WF+OCE_OTH+AQ+GS+TF+RNC+OTH.REACH.TOTAL.NR.T.EU27_2020+BE+BG+CZ+DK+DE+EE+IE+EL+ES+FR+HR+IT+CY+LV+LT+LU+HU+MT+NL+AT+PL+PT+RO+SI+SK+FI+SE+IS+LI+NO+CH+UK+BA+ME+MD+MK+TR+UA+BY+RU+SM+KG+TJ+UZ+AM+AZ+IL/?format=SDMX-CSV&startPeriod=1998&endPeriod=2021&lang=en&label=label_only")
df_imm_labels.rename(columns={"OBS_VALUE":"Immigrants"}, inplace=True)
df_imm_labels
# Out:
#                        DATAFLOW        LAST UPDATE    freq   partner  \
# 0       ESTAT:MIGR_IMM5PRV(1.0)  24/10/23 23:00:00  Annual   Andorra
# 1       ESTAT:MIGR_IMM5PRV(1.0)  24/10/23 23:00:00  Annual   Andorra
# 2       ESTAT:MIGR_IMM5PRV(1.0)  24/10/23 23:00:00  Annual   Andorra
# 3       ESTAT:MIGR_IMM5PRV(1.0)  24/10/23 23:00:00  Annual   Andorra
# 4       ESTAT:MIGR_IMM5PRV(1.0)  24/10/23 23:00:00  Annual   Andorra
# ...                         ...                ...     ...       ...
# 109720  ESTAT:MIGR_IMM5PRV(1.0)  24/10/23 23:00:00  Annual  Zimbabwe
# 109721  ESTAT:MIGR_IMM5PRV(1.0)  24/10/23 23:00:00  Annual  Zimbabwe
# 109722  ESTAT:MIGR_IMM5PRV(1.0)  24/10/23 23:00:00  Annual  Zimbabwe
# 109723  ESTAT:MIGR_IMM5PRV(1.0)  24/10/23 23:00:00  Annual  Zimbabwe
# 109724  ESTAT:MIGR_IMM5PRV(1.0)  24/10/23 23:00:00  Annual  Zimbabwe
#
#                              agedef    age    unit    sex             geo  \
# 0       Age reached during the year  Total  Number  Total         Austria
# 1       Age reached during the year  Total  Number  Total         Austria
# 2       Age reached during the year  Total  Number  Total         Austria
# 3       Age reached during the year  Total  Number  Total         Austria
# 4       Age reached during the year  Total  Number  Total         Austria
# ...                             ...    ...     ...    ...             ...
# 109720  Age reached during the year  Total  Number  Total  United Kingdom
# 109721  Age reached during the year  Total  Number  Total  United Kingdom
# 109722  Age reached during the year  Total  Number  Total  United Kingdom
# 109723  Age reached during the year  Total  Number  Total  United Kingdom
# 109724  Age reached during the year  Total  Number  Total  United Kingdom
#
#         TIME_PERIOD  Immigrants OBS_FLAG
# 0              1998        10.0      NaN
# 1              1999         3.0      NaN
# 2              2000         1.0      NaN
# 3              2001         0.0      NaN
# 4              2002         0.0        b
# ...             ...         ...      ...
# 109720         2001      5319.0      NaN
# 109721         2002      5453.0      NaN
# 109722         2003      7358.0      NaN
# 109723         2004      9086.0      NaN
# 109724         2005      7131.0      NaN
#
# [109725 rows x 12 columns]

# %%
# create a table which shows total immigration regardless of partner
df_imm_total = df_imm_labels[df_imm_labels["partner"] == "Total"]
df_imm_total
# Out:
#                       DATAFLOW        LAST UPDATE    freq partner  \
# 98218  ESTAT:MIGR_IMM5PRV(1.0)  24/10/23 23:00:00  Annual   Total
# 98219  ESTAT:MIGR_IMM5PRV(1.0)  24/10/23 23:00:00  Annual   Total
# 98220  ESTAT:MIGR_IMM5PRV(1.0)  24/10/23 23:00:00  Annual   Total
# 98221  ESTAT:MIGR_IMM5PRV(1.0)  24/10/23 23:00:00  Annual   Total
# 98222  ESTAT:MIGR_IMM5PRV(1.0)  24/10/23 23:00:00  Annual   Total
# ...                        ...                ...     ...     ...
# 98968  ESTAT:MIGR_IMM5PRV(1.0)  24/10/23 23:00:00  Annual   Total
# 98969  ESTAT:MIGR_IMM5PRV(1.0)  24/10/23 23:00:00  Annual   Total
# 98970  ESTAT:MIGR_IMM5PRV(1.0)  24/10/23 23:00:00  Annual   Total
# 98971  ESTAT:MIGR_IMM5PRV(1.0)  24/10/23 23:00:00  Annual   Total
# 98972  ESTAT:MIGR_IMM5PRV(1.0)  24/10/23 23:00:00  Annual   Total
#
#                             agedef    age    unit    sex             geo  \
# 98218  Age reached during the year  Total  Number  Total         Armenia
# 98219  Age reached during the year  Total  Number  Total         Armenia
# 98220  Age reached during the year  Total  Number  Total         Armenia
# 98221  Age reached during the year  Total  Number  Total         Austria
# 98222  Age reached during the year  Total  Number  Total         Austria
# ...                            ...    ...     ...    ...             ...
# 98968  Age reached during the year  Total  Number  Total  United Kingdom
# 98969  Age reached during the year  Total  Number  Total  United Kingdom
# 98970  Age reached during the year  Total  Number  Total  United Kingdom
# 98971  Age reached during the year  Total  Number  Total  United Kingdom
# 98972  Age reached during the year  Total  Number  Total      Uzbekistan
#
#        TIME_PERIOD  Immigrants OBS_FLAG
# 98218         2005      1497.0      NaN
# 98219         2006      1335.0      NaN
# 98220         2007      1112.0      NaN
# 98221         1998     72723.0      NaN
# 98222         1999     86710.0      NaN
# ...            ...         ...      ...
# 98968         2016    588993.0      NaN
# 98969         2017    644209.0      NaN
# 98970         2018    603953.0        p
# 98971         2019    680906.0      NaN
# 98972         2006      6418.0      NaN
#
# [755 rows x 12 columns]

# %%
px.scatter(df_imm_total[df_imm_total["geo"] != "European Union - 27 countries (from 2020)"], x="TIME_PERIOD", y="Immigrants", color="geo")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d752139e-3838-477f-bd07-cc1d5dbba338" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d752139e-3838-477f-bd07-cc1d5dbba338")) {                    Plotly.newPlot(                        "d752139e-3838-477f-bd07-cc1d5dbba338",                        [{"hovertemplate":"geo=Armenia\u003cbr\u003eTIME_PERIOD=%{x}\u003cbr\u003eImmigrants=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Armenia","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Armenia","orientation":"v","showlegend":true,"x":[2005,2006,2007],"xaxis":"x","y":[1497.0,1335.0,1112.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"geo=Austria\u003cbr\u003eTIME_PERIOD=%{x}\u003cbr\u003eImmigrants=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Austria","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Austria","orientation":"v","showlegend":true,"x":[1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[72723.0,86710.0,81675.0,89928.0,108125.0,111869.0,122547.0,114465.0,98535.0,72862.0,73772.0,69295.0,70978.0,82230.0,91557.0,101866.0,116262.0,166323.0,129509.0,111801.0,105633.0,109167.0,103565.0,118511.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"geo=Azerbaijan\u003cbr\u003eTIME_PERIOD=%{x}\u003cbr\u003eImmigrants=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Azerbaijan","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"Azerbaijan","orientation":"v","showlegend":true,"x":[2005,2007],"xaxis":"x","y":[2013.0,1954.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"geo=Bosnia and Herzegovina\u003cbr\u003eTIME_PERIOD=%{x}\u003cbr\u003eImmigrants=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bosnia and Herzegovina","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"Bosnia and Herzegovina","orientation":"v","showlegend":true,"x":[2007],"xaxis":"x","y":[5620.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"geo=Belgium\u003cbr\u003eTIME_PERIOD=%{x}\u003cbr\u003eImmigrants=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Belgium","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"Belgium","orientation":"v","showlegend":true,"x":[1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[83812.0,91624.0,89388.0,110410.0,113857.0,112060.0,117236.0,132810.0,137699.0,146409.0,135281.0,147377.0,129477.0,120078.0,123158.0,146626.0,123702.0,126703.0,137860.0,150006.0,118683.0,139743.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"geo=Bulgaria\u003cbr\u003eTIME_PERIOD=%{x}\u003cbr\u003eImmigrants=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bulgaria","marker":{"color":"#19d3f3","symbol":"circle"},"mode":"markers","name":"Bulgaria","orientation":"v","showlegend":true,"x":[2007,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[1561.0,14103.0,18570.0,26615.0,25223.0,21241.0,25597.0,29559.0,37929.0,37364.0,39461.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"geo=Belarus\u003cbr\u003eTIME_PERIOD=%{x}\u003cbr\u003eImmigrants=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Belarus","marker":{"color":"#FF6692","symbol":"circle"},"mode":"markers","name":"Belarus","orientation":"v","showlegend":true,"x":[2005,2006,2007],"xaxis":"x","y":[13031.0,14124.0,14155.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"geo=Switzerland\u003cbr\u003eTIME_PERIOD=%{x}\u003cbr\u003eImmigrants=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Switzerland","marker":{"color":"#B6E880","symbol":"circle"},"mode":"mark ...

# %%
# maybe do immigrants / pop

# %% [markdown]
# # Average Rating of Life Satisfaction
# https://ec.europa.eu/eurostat/databrowser/view/ilc_pw01__custom_8469540/default/table?lang=en&page=time:2018

# %%
# df_satis = pd.read_csv("https://ec.europa.eu/eurostat/api/dissemination/sdmx/2.1/data/ilc_pw01/A.RTG.TOTAL+ED0-2+ED3_4+ED5-8.LIFESAT.T+M+F.Y16-19+Y16-24+Y16-29+Y_GE16+Y20-24+Y25-29+Y25-34+Y25-64+Y35-49+Y50-64+Y65-74+Y_GE65+Y_GE75.EU+EU27_2020+EU28+BE+BG+CZ+DK+DE+EE+IE+EL+ES+FR+HR+IT+CY+LV+LT+LU+HU+MT+NL+AT+PL+PT+RO+SI+SK+FI+SE+IS+NO+CH+UK+RS+TR+ME+MK+AL+XK/?format=SDMX-CSV&startPeriod=2013&endPeriod=2022")
# df_satis

# isced11 = international standard classifiction of education

# %%
# # this would be the avg of all b/c >= 16 yrs
# df_satis_all = df_satis[(df_satis["age"] == "Y_GE16") & (df_satis["sex"] == "T") & (df_satis["isced11"] == "TOTAL")]
# df_satis_all

# %%
# px.scatter(df_satis_all, x="TIME_PERIOD", y="OBS_VALUE", color="geo")

# %%
# px.line(df_satis_all, x="TIME_PERIOD", y="OBS_VALUE", color="geo", markers=True)

# %%
df_satis_label = pd.read_csv("https://ec.europa.eu/eurostat/api/dissemination/sdmx/2.1/data/ilc_pw01/?format=SDMX-CSV&lang=en&label=label_only")
df_satis_label.rename(columns={"OBS_VALUE": "Life Satisfaction"}, inplace=True)

# %%
df_satis_label["isced11"].value_counts()
# Out:
# Less than primary, primary and lower secondary education (levels 0-2)                 25563
# Upper secondary and post-secondary non-tertiary education (levels 3 and 4)            25563
# All ISCED 2011 levels                                                                 25563
# Tertiary education (levels 5-8)                                                       25353
# Short-cycle tertiary education and Bachelor's or equivalent level (levels 5 and 6)     2310
# Name: isced11, dtype: int64

# %%
df_satis_label["age"].value_counts()
# Out:
# From 16 to 24 years    8328
# From 25 to 34 years    8328
# From 35 to 49 years    8328
# From 50 to 64 years    8328
# From 65 to 74 years    8328
# 16 years or over       8328
# 75 years or over       8328
# From 25 to 64 years    7716
# 65 years or over       7716
# From 16 to 19 years    7656
# From 16 to 29 years    7656
# From 20 to 24 years    7656
# From 25 to 29 years    7656
# Name: age, dtype: int64

# %%
df_satis_label = df_satis_label[(df_satis_label["sex"] == "Total") & (df_satis_label["isced11"] == "All ISCED 2011 levels") & (df_satis_label["indic_wb"] == "Overall life satisfaction") & (df_satis_label["age"] == "16 years or over")]
px.line(df_satis_label, x="TIME_PERIOD", y="Life Satisfaction", color="geo", markers=True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="84e7ab63-caab-40bc-81f4-238098dc05b8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("84e7ab63-caab-40bc-81f4-238098dc05b8")) {                    Plotly.newPlot(                        "84e7ab63-caab-40bc-81f4-238098dc05b8",                        [{"hovertemplate":"geo=Albania\u003cbr\u003eTIME_PERIOD=%{x}\u003cbr\u003eLife Satisfaction=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Albania","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"Albania","orientation":"v","showlegend":true,"x":[2018,2021],"xaxis":"x","y":[5.5,5.7],"yaxis":"y","type":"scatter"},{"hovertemplate":"geo=Austria\u003cbr\u003eTIME_PERIOD=%{x}\u003cbr\u003eLife Satisfaction=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Austria","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"Austria","orientation":"v","showlegend":true,"x":[2013,2018,2021,2022],"xaxis":"x","y":[7.8,8.0,8.0,7.9],"yaxis":"y","type":"scatter"},{"hovertemplate":"geo=Belgium\u003cbr\u003eTIME_PERIOD=%{x}\u003cbr\u003eLife Satisfaction=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Belgium","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"Belgium","orientation":"v","showlegend":true,"x":[2013,2018,2021,2022],"xaxis":"x","y":[7.6,7.6,7.5,7.6],"yaxis":"y","type":"scatter"},{"hovertemplate":"geo=Bulgaria\u003cbr\u003eTIME_PERIOD=%{x}\u003cbr\u003eLife Satisfaction=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bulgaria","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"Bulgaria","orientation":"v","showlegend":true,"x":[2013,2018,2021,2022],"xaxis":"x","y":[4.8,5.4,5.7,5.6],"yaxis":"y","type":"scatter"},{"hovertemplate":"geo=Switzerland\u003cbr\u003eTIME_PERIOD=%{x}\u003cbr\u003eLife Satisfaction=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Switzerland","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"Switzerland","orientation":"v","showlegend":true,"x":[2013,2018,2021,2022],"xaxis":"x","y":[8.0,8.0,7.9,8.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"geo=Cyprus\u003cbr\u003eTIME_PERIOD=%{x}\u003cbr\u003eLife Satisfaction=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cyprus","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"Cyprus","orientation":"v","showlegend":true,"x":[2013,2018,2021,2022],"xaxis":"x","y":[6.2,7.1,6.8,7.2],"yaxis":"y","type":"scatter"},{"hovertemplate":"geo=Czechia\u003cbr\u003eTIME_PERIOD=%{x}\u003cbr\u003eLife Satisfaction=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Czechia","line":{"color":"#FF6692","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"Czechia","orientation":"v","showlegend":true,"x":[2013,2018,2021,2022],"xaxis":"x","y":[6.9,7.4,7.3,7.4],"yaxis":"y","type":"scatter"},{"hovertemplate":"geo=Germany\u003cbr\u003eTIME_PERIOD=%{x}\u003cbr\u003eLife Satisfaction=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Germany","line":{"color":"#B6E880","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"Germany","orientation":"v","showlegend":true,"x":[2013,2018,2021,2022],"xaxis":"x","y":[7.3,7.4,7.1,6.5],"yaxis":"y","type":"scatter"},{"hovertemplate":"geo=Denmark\u003cbr\u003eTIME_PERIOD=%{x}\u003cbr\u003eLife Satisfaction=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Denmark","line":{"color":"#FF97FF","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","na ...

# %% [markdown]
# # Housing
# https://ec.europa.eu/eurostat/databrowser/product/view/prc_hpi_a

# %%
# df_housing = pd.read_csv("https://ec.europa.eu/eurostat/api/dissemination/sdmx/2.1/data/ei_hppi_q/?format=SDMX-CSV&lang=en&label=label_only")
# df_housing

# %%
# df_housing = df_housing[df_housing["unit"] == "Index, 2015=100 (NSA)"]
# df_housing

# %%
# def quart_to_float(time):
#   year = time[0:4]
#   dec = int(time[-1]) * 2
#   return float(f"{year}.{dec}")

# df_housing["year_float"] = df_housing["TIME_PERIOD"].map(quart_to_float)
# df_housing

# %%
# px.scatter(df_housing, x="year_float", y="OBS_VALUE", color="geo", title="Housing Index Over Time")

# %%
df_housing_ann = pd.read_csv("https://ec.europa.eu/eurostat/api/dissemination/sdmx/2.1/data/prc_hpi_a/A.TOTAL+DW_NEW+DW_EXST.I15_A_AVG.EU+EU27_2020+EU28+EA+EA20+EA19+BE+BG+CZ+DK+DE+EE+IE+ES+FR+HR+IT+CY+LV+LT+LU+HU+MT+NL+AT+PL+PT+RO+SI+SK+FI+SE+IS+NO+CH+UK+TR/?format=SDMX-CSV&startPeriod=2005&endPeriod=2022&lang=en&label=label_only")
df_housing_ann = df_housing_ann[df_housing_ann["purchase"] == "Total"]
df_housing_ann.rename(columns={"OBS_VALUE":"Housing Index"}, inplace=True)

# %%
px.scatter(df_housing_ann, x="TIME_PERIOD", y="Housing Index", color="geo", title="Housing Index Over Time")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="94175108-7c28-419d-8419-83a54935461e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("94175108-7c28-419d-8419-83a54935461e")) {                    Plotly.newPlot(                        "94175108-7c28-419d-8419-83a54935461e",                        [{"hovertemplate":"geo=Austria\u003cbr\u003eTIME_PERIOD=%{x}\u003cbr\u003eHousing Index=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Austria","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Austria","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[76.8,81.6,87.57,92.1,95.33,100.0,108.53,114.26,119.64,126.6,136.31,153.26,170.77],"yaxis":"y","type":"scatter"},{"hovertemplate":"geo=Belgium\u003cbr\u003eTIME_PERIOD=%{x}\u003cbr\u003eHousing Index=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Belgium","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Belgium","orientation":"v","showlegend":true,"x":[2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[72.49,79.56,85.76,89.54,89.12,91.92,95.61,97.75,98.9,98.35,100.0,102.64,106.37,109.42,113.78,118.6,127.06,134.19],"yaxis":"y","type":"scatter"},{"hovertemplate":"geo=Bulgaria\u003cbr\u003eTIME_PERIOD=%{x}\u003cbr\u003eHousing Index=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bulgaria","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"Bulgaria","orientation":"v","showlegend":true,"x":[2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[80.09,91.86,118.42,147.97,117.79,105.81,99.98,98.07,95.92,97.29,100.0,107.02,116.3,123.96,131.42,137.41,149.33,169.92],"yaxis":"y","type":"scatter"},{"hovertemplate":"geo=Cyprus\u003cbr\u003eTIME_PERIOD=%{x}\u003cbr\u003eHousing Index=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cyprus","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"Cyprus","orientation":"v","showlegend":true,"x":[2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[97.06,108.57,121.32,128.17,119.76,112.9,111.09,107.7,103.29,101.47,100.0,100.27,102.52,104.32,108.2,107.98,104.33,107.71],"yaxis":"y","type":"scatter"},{"hovertemplate":"geo=Czechia\u003cbr\u003eTIME_PERIOD=%{x}\u003cbr\u003eHousing Index=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Czechia","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"Czechia","orientation":"v","showlegend":true,"x":[2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[100.8,96.9,95.2,95.3,93.9,93.9,96.2,100.0,107.2,119.7,130.0,141.9,153.9,184.2,215.3],"yaxis":"y","type":"scatter"},{"hovertemplate":"geo=Germany\u003cbr\u003eTIME_PERIOD=%{x}\u003cbr\u003eHousing Index=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Germany","marker":{"color":"#19d3f3","symbol":"circle"},"mode":"markers","name":"Germany","orientation":"v","showlegend":true,"x":[2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[83.3,83.0,81.2,82.3,83.0,83.9,86.8,89.8,92.6,95.5,100.0,107.5,114.1,121.7,128.7,138.7,154.7,162.9],"yaxis":"y","type":"scatter"},{"hovertemplate":"geo=Denmark\u003cbr\u003eTIME_PERIOD=%{x}\u003cbr\u003eHousing Index=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Denmark","marker":{"color":"#FF6692","symbol":"circle"},"mode":"markers","name":"Denmark","orientation":"v","showlegend":true,"x":[2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019 ...

# %% [markdown]
# # Population
# https://ec.europa.eu/eurostat/databrowser/view/demo_gind__custom_8449795/default/table?lang=en

# %%
df_pop = pd.read_csv("https://ec.europa.eu/eurostat/api/dissemination/sdmx/2.1/data/demo_gind/A.AVG+CNMIGRAT+CNMIGRATRT+DEATH+FAVG.EU27_2020+EU28+EA20+EA19+BE+BG+CZ+DK+DE+DE_TOT+EE+IE+EL+ES+FR+FX+HR+IT+CY+LV+LT+LU+HU+MT+NL+AT+PL+PT+RO+SI+SK+FI+SE+EEA31+EFTA+IS+LI+NO+CH+UK+BA+ME+MD+MK+AL+RS+TR+UA+XK+GE+AD+BY+MC+RU+SM+AM+AZ/?format=SDMX-CSV&startPeriod=1960&endPeriod=2023&lang=en&label=label_only")
df_pop
# Out:
#                    DATAFLOW        LAST UPDATE    freq  \
# 0      ESTAT:DEMO_GIND(1.0)  27/11/23 23:00:00  Annual
# 1      ESTAT:DEMO_GIND(1.0)  27/11/23 23:00:00  Annual
# 2      ESTAT:DEMO_GIND(1.0)  27/11/23 23:00:00  Annual
# 3      ESTAT:DEMO_GIND(1.0)  27/11/23 23:00:00  Annual
# 4      ESTAT:DEMO_GIND(1.0)  27/11/23 23:00:00  Annual
# ...                     ...                ...     ...
# 14252  ESTAT:DEMO_GIND(1.0)  27/11/23 23:00:00  Annual
# 14253  ESTAT:DEMO_GIND(1.0)  27/11/23 23:00:00  Annual
# 14254  ESTAT:DEMO_GIND(1.0)  27/11/23 23:00:00  Annual
# 14255  ESTAT:DEMO_GIND(1.0)  27/11/23 23:00:00  Annual
# 14256  ESTAT:DEMO_GIND(1.0)  27/11/23 23:00:00  Annual
#
#                            indic_de      geo  TIME_PERIOD  OBS_VALUE OBS_FLAG
# 0        Average population - total  Andorra         1986    45785.0      NaN
# 1        Average population - total  Andorra         1987    47714.0      NaN
# 2        Average population - total  Andorra         1988    49490.0      NaN
# 3        Average population - total  Andorra         1989    50708.0      NaN
# 4        Average population - total  Andorra         1990    52697.0      NaN
# ...                             ...      ...          ...        ...      ...
# 14252  Average population - females  Kosovo*         2015   892682.0        e
# 14253  Average population - females  Kosovo*         2016   894807.0        e
# 14254  Average population - females  Kosovo*         2017   905829.0        e
# 14255  Average population - females  Kosovo*         2018   910304.0      NaN
# 14256  Average population - females  Kosovo*         2019   908744.0      NaN
#
# [14257 rows x 8 columns]

# %%
df_pop = df_pop[df_pop["indic_de"] == "Average population - total"]
df_pop.rename(columns={"OBS_VALUE": "Population"}, inplace=True)
px.scatter(df_pop, x="TIME_PERIOD", y="Population", color="geo")
# Out:
# <ipython-input-277-d969596f92dd>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="1cf854ae-46ca-4844-b15a-6458ef88e177" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1cf854ae-46ca-4844-b15a-6458ef88e177")) {                    Plotly.newPlot(                        "1cf854ae-46ca-4844-b15a-6458ef88e177",                        [{"hovertemplate":"geo=Andorra\u003cbr\u003eTIME_PERIOD=%{x}\u003cbr\u003ePopulation=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Andorra","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Andorra","showlegend":true,"x":[1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2016,2018,2019,2022],"xaxis":"x","y":[45785.0,47714.0,49490.0,50708.0,52697.0,56778.0,60324.0,63413.0,64769.0,64085.0,64169.0,64893.0,65592.0,65924.0,65908.0,66089.0,66747.0,69740.0,74598.0,77712.0,79886.0,82180.0,83811.0,84283.0,84549.0,78115.0,77181.0,72419.0,75486.0,76860.0,80562.0],"yaxis":"y","type":"scattergl"},{"hovertemplate":"geo=Albania\u003cbr\u003eTIME_PERIOD=%{x}\u003cbr\u003ePopulation=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Albania","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Albania","showlegend":true,"x":[1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[1608800.0,1659800.0,1711319.0,1762621.0,1814135.0,1864791.0,1914573.0,1965598.0,2022272.0,2081695.0,2135479.0,2187853.0,2243126.0,2296752.0,2350124.0,2404831.0,2458526.0,2513546.0,2566266.0,2617832.0,2671997.0,2726056.0,2784278.0,2843960.0,2904429.0,2964762.0,3022635.0,3083605.0,3142336.0,3211964.0,3266790.0,3247039.0,3227287.0,3207536.0,3187784.0,3168033.0,3148281.0,3128530.0,3108778.0,3089027.0,3060173.0,3060169.0,3051006.0,3039612.0,3026933.0,3011482.0,2992542.0,2970011.0,2947311.0,2927515.0,2913018.0,2905185.0,2900389.0,2895082.0,2889095.0,2880694.0,2876092.0,2873458.0,2866376.0,2854191.0,2837848.0,2811667.0,2777689.0],"yaxis":"y","type":"scattergl"},{"hovertemplate":"geo=Armenia\u003cbr\u003eTIME_PERIOD=%{x}\u003cbr\u003ePopulation=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Armenia","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"Armenia","showlegend":true,"x":[1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[3247400.0,3242100.0,3235150.0,3229500.0,3221100.0,3214100.0,3211600.0,3211250.0,3214000.0,3217517.0,3221094.0,3226520.0,3234031.0,3243729.0,3256066.0,3268468.0,3004588.0,2992364.0,2979442.0,2969001.0,2962482.0,2961473.0],"yaxis":"y","type":"scattergl"},{"hovertemplate":"geo=Austria\u003cbr\u003eTIME_PERIOD=%{x}\u003cbr\u003ePopulation=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Austria","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"Austria","showlegend":true,"x":[1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[7047539.0,7086299.0,7129864.0,7175811.0,7223801.0,7270889.0,7322066.0,7376998.0,7415403.0,7441055.0,7467086.0,7500482.0,7544201.0,7586115.0,7599038.0,7578903.0,7565525.0,7568430.0,7562305.0,7549425.0,7549433.0,7568710.0,7574140.0,7561910.0, ...

# %%
df_pop["geo"].value_counts()
# Out:
# Croatia                                                     63
# Malta                                                       63
# European Union - 27 countries (from 2020)                   63
# Finland                                                     63
# Sweden                                                      63
# Romania                                                     63
# Portugal                                                    63
# Albania                                                     63
# Hungary                                                     63
# Ireland                                                     63
# Iceland                                                     63
# Italy                                                       63
# Liechtenstein                                               63
# Lithuania                                                   63
# Luxembourg                                                  63
# Latvia                                                      63
# Poland                                                      63
# Norway                                                      63
# Netherlands                                                 63
# Spain                                                       63
# Greece                                                      63
# European Free Trade Association                             63
# Czechia                                                     63
# Austria                                                     63
# Türkiye                                                     63
# Belgium                                                     63
# Bulgaria                                                    63
# Slovakia                                                    63
# Switzerland                                                 63
# Cyprus                                                      63
# Germany                                                     63
# Germany including former GDR                                63
# Denmark                                                     63
# Euro area - 19 countries  (2015-2022)                       63
# Slovenia                                                    63
# Estonia                                                     63
# North Macedonia                                             63
# European Economic Area (EU28 - 2013-2020 and IS, LI, NO)    60
# United Kingdom                                              60
# Bosnia and Herzegovina                                      59
# European Union - 28 countries (2013-2020)                   59
# Kosovo*                                                     55
# France (metropolitan)                                       53
# France                                                      41
# Andorra                                                     31
# Montenegro                                                  28
# Serbia                                                      28
# Azerbaijan                                                  27
# Moldova                                                     26
# Ukraine                                                     25
# Georgia                                                     24
# Belarus                                                     24
# Armenia                                                     22
# San Marino                                                  17
# Russia                                                      16
# Euro area – 20 countries (from 2023)                        13
# Monaco                                                       4
# Name: geo, dtype: int64

# %%
df_pop
# Out:
#                   DATAFLOW        LAST UPDATE    freq  \
# 0     ESTAT:DEMO_GIND(1.0)  27/11/23 23:00:00  Annual
# 1     ESTAT:DEMO_GIND(1.0)  27/11/23 23:00:00  Annual
# 2     ESTAT:DEMO_GIND(1.0)  27/11/23 23:00:00  Annual
# 3     ESTAT:DEMO_GIND(1.0)  27/11/23 23:00:00  Annual
# 4     ESTAT:DEMO_GIND(1.0)  27/11/23 23:00:00  Annual
# ...                    ...                ...     ...
# 2998  ESTAT:DEMO_GIND(1.0)  27/11/23 23:00:00  Annual
# 2999  ESTAT:DEMO_GIND(1.0)  27/11/23 23:00:00  Annual
# 3000  ESTAT:DEMO_GIND(1.0)  27/11/23 23:00:00  Annual
# 3001  ESTAT:DEMO_GIND(1.0)  27/11/23 23:00:00  Annual
# 3002  ESTAT:DEMO_GIND(1.0)  27/11/23 23:00:00  Annual
#
#                         indic_de      geo  TIME_PERIOD  Population OBS_FLAG
# 0     Average population - total  Andorra         1986     45785.0      NaN
# 1     Average population - total  Andorra         1987     47714.0      NaN
# 2     Average population - total  Andorra         1988     49490.0      NaN
# 3     Average population - total  Andorra         1989     50708.0      NaN
# 4     Average population - total  Andorra         1990     52697.0      NaN
# ...                          ...      ...          ...         ...      ...
# 2998  Average population - total  Kosovo*         2016   1777568.0        e
# 2999  Average population - total  Kosovo*         2017   1791019.0        e
# 3000  Average population - total  Kosovo*         2018   1797086.0      NaN
# 3001  Average population - total  Kosovo*         2019   1788891.0      NaN
# 3002  Average population - total  Kosovo*         2020   1790152.0        e
#
# [3003 rows x 8 columns]

# %%
euro_mask = ((df_pop["geo"] == "European Union - 27 countries (from 2020)") | (df_pop["geo"] == "Euro area - 19 countries  (2015-2022)") |
            (df_pop["geo"] == "European Union - 28 countries (2013-2020)") | (df_pop["geo"] == "European Economic Area (EU28 - 2013-2020 and IS, LI, NO)") |
            (df_pop["geo"] == "Euro area – 20 countries (from 2023)"))
df_pop_countries = df_pop[~euro_mask]
df_pop_countries.rename(columns={"OBS_VALUE": "Population"}, inplace=True)
df_pop_countries
# Out:
# <ipython-input-280-03f70c493cb7>:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                   DATAFLOW        LAST UPDATE    freq  \
# 0     ESTAT:DEMO_GIND(1.0)  27/11/23 23:00:00  Annual
# 1     ESTAT:DEMO_GIND(1.0)  27/11/23 23:00:00  Annual
# 2     ESTAT:DEMO_GIND(1.0)  27/11/23 23:00:00  Annual
# 3     ESTAT:DEMO_GIND(1.0)  27/11/23 23:00:00  Annual
# 4     ESTAT:DEMO_GIND(1.0)  27/11/23 23:00:00  Annual
# ...                    ...                ...     ...
# 2998  ESTAT:DEMO_GIND(1.0)  27/11/23 23:00:00  Annual
# 2999  ESTAT:DEMO_GIND(1.0)  27/11/23 23:00:00  Annual
# 3000  ESTAT:DEMO_GIND(1.0)  27/11/23 23:00:00  Annual
# 3001  ESTAT:DEMO_GIND(1.0)  27/11/23 23:00:00  Annual
# 3002  ESTAT:DEMO_GIND(1.0)  27/11/23 23:00:00  Annual
#
#                         indic_de      geo  TIME_PERIOD  Population OBS_FLAG
# 0     Average population - total  Andorra         1986     45785.0      NaN
# 1     Average population - total  Andorra         1987     47714.0      NaN
# 2     Average population - total  Andorra         1988     49490.0      NaN
# 3     Average population - total  Andorra         1989     50708.0      NaN
# 4     Average population - total  Andorra         1990     52697.0      NaN
# ...                          ...      ...          ...         ...      ...
# 2998  Average population - total  Kosovo*         2016   1777568.0        e
# 2999  Average population - total  Kosovo*         2017   1791019.0        e
# 3000  Average population - total  Kosovo*         2018   1797086.0      NaN
# 3001  Average population - total  Kosovo*         2019   1788891.0      NaN
# 3002  Average population - total  Kosovo*         2020   1790152.0        e
#
# [2745 rows x 8 columns]

# %%
px.scatter(df_pop_countries, x="TIME_PERIOD", y="Population", color="geo", title="Country Population Over Time")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e1d4a11c-1cd8-4062-badb-b5773537d385" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e1d4a11c-1cd8-4062-badb-b5773537d385")) {                    Plotly.newPlot(                        "e1d4a11c-1cd8-4062-badb-b5773537d385",                        [{"hovertemplate":"geo=Andorra\u003cbr\u003eTIME_PERIOD=%{x}\u003cbr\u003ePopulation=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Andorra","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Andorra","showlegend":true,"x":[1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2016,2018,2019,2022],"xaxis":"x","y":[45785.0,47714.0,49490.0,50708.0,52697.0,56778.0,60324.0,63413.0,64769.0,64085.0,64169.0,64893.0,65592.0,65924.0,65908.0,66089.0,66747.0,69740.0,74598.0,77712.0,79886.0,82180.0,83811.0,84283.0,84549.0,78115.0,77181.0,72419.0,75486.0,76860.0,80562.0],"yaxis":"y","type":"scattergl"},{"hovertemplate":"geo=Albania\u003cbr\u003eTIME_PERIOD=%{x}\u003cbr\u003ePopulation=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Albania","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Albania","showlegend":true,"x":[1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[1608800.0,1659800.0,1711319.0,1762621.0,1814135.0,1864791.0,1914573.0,1965598.0,2022272.0,2081695.0,2135479.0,2187853.0,2243126.0,2296752.0,2350124.0,2404831.0,2458526.0,2513546.0,2566266.0,2617832.0,2671997.0,2726056.0,2784278.0,2843960.0,2904429.0,2964762.0,3022635.0,3083605.0,3142336.0,3211964.0,3266790.0,3247039.0,3227287.0,3207536.0,3187784.0,3168033.0,3148281.0,3128530.0,3108778.0,3089027.0,3060173.0,3060169.0,3051006.0,3039612.0,3026933.0,3011482.0,2992542.0,2970011.0,2947311.0,2927515.0,2913018.0,2905185.0,2900389.0,2895082.0,2889095.0,2880694.0,2876092.0,2873458.0,2866376.0,2854191.0,2837848.0,2811667.0,2777689.0],"yaxis":"y","type":"scattergl"},{"hovertemplate":"geo=Armenia\u003cbr\u003eTIME_PERIOD=%{x}\u003cbr\u003ePopulation=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Armenia","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"Armenia","showlegend":true,"x":[1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[3247400.0,3242100.0,3235150.0,3229500.0,3221100.0,3214100.0,3211600.0,3211250.0,3214000.0,3217517.0,3221094.0,3226520.0,3234031.0,3243729.0,3256066.0,3268468.0,3004588.0,2992364.0,2979442.0,2969001.0,2962482.0,2961473.0],"yaxis":"y","type":"scattergl"},{"hovertemplate":"geo=Austria\u003cbr\u003eTIME_PERIOD=%{x}\u003cbr\u003ePopulation=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Austria","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"Austria","showlegend":true,"x":[1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[7047539.0,7086299.0,7129864.0,7175811.0,7223801.0,7270889.0,7322066.0,7376998.0,7415403.0,7441055.0,7467086.0,7500482.0,7544201.0,7586115.0,7599038.0,7578903.0,7565525.0,7568430.0,7562305.0,7549425.0,7549433.0,7568710.0,7574140.0,7561910.0, ...

# %% [markdown]
# # Combining Into 1 DataFrame

# %%
df_cpi_label = df_cpi_label.drop(["DATAFLOW", "LAST UPDATE", "freq", "unit", "coicop", "OBS_FLAG"], axis=1)
df_imm_total = df_imm_total.drop(["DATAFLOW", "LAST UPDATE", "freq", "partner", "age", "agedef", "unit", "sex", "OBS_FLAG"], axis=1)
df_satis_label = df_satis_label.drop(["DATAFLOW", "LAST UPDATE", "freq", "age", "unit", "isced11", "indic_wb", "sex", "OBS_FLAG"], axis=1)
df_housing_ann = df_housing_ann.drop(["DATAFLOW", "LAST UPDATE", "freq", "purchase", "unit", "OBS_FLAG"], axis=1)
df_pop = df_pop.drop(["DATAFLOW", "LAST UPDATE", "freq", "indic_de", "OBS_FLAG"], axis=1)

# %%
df_eurostat = df_cpi_label.merge(df_imm_total, on=["geo", "TIME_PERIOD"], how="outer")
df_eurostat = df_eurostat.merge(df_satis_label, on=["geo", "TIME_PERIOD"], how="outer")
df_eurostat = df_eurostat.merge(df_pop, on=["geo", "TIME_PERIOD"], how="outer")
df_eurostat = df_eurostat.merge(df_housing_ann, on=["geo", "TIME_PERIOD"], how="outer")
df_eurostat
# Out:
#           geo  TIME_PERIOD     CPI  Immigrants  Life Satisfaction  Population  \
# 0     Albania         2016  101.51         NaN                NaN   2876092.0
# 1     Albania         2017  104.76         NaN                NaN   2873458.0
# 2     Albania         2018  106.59         NaN                5.5   2866376.0
# 3     Albania         2019  108.39         NaN                NaN   2854191.0
# 4     Albania         2020  110.74         NaN                NaN   2837848.0
# ...       ...          ...     ...         ...                ...         ...
# 3120  Kosovo*         2011     NaN         NaN                NaN   1787101.0
# 3121  Kosovo*         2012     NaN         NaN                NaN   1797814.0
# 3122  Kosovo*         2013     NaN         NaN                NaN   1818119.0
# 3123  Kosovo*         2014     NaN         NaN                NaN   1812788.0
# 3124  Kosovo*         2015     NaN         NaN                NaN   1788274.0
#
#       Housing Index
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 3120            NaN
# 3121            NaN
# 3122            NaN
# 3123            NaN
# 3124            NaN
#
# [3125 rows x 7 columns]

# %%
df_eurostat.to_csv('sd_eurostat.csv')

# %%
df_test = df_eurostat.drop(columns=["Life Satisfaction"]).dropna()
df_test
# Out:
#                  geo  TIME_PERIOD     CPI  Immigrants  Population  \
# 21           Austria         2010   90.14     70978.0   8363404.0
# 22           Austria         2011   93.35     82230.0   8391643.0
# 23           Austria         2012   95.75     91557.0   8429991.0
# 24           Austria         2013   97.77    101866.0   8479823.0
# 25           Austria         2014   99.20    116262.0   8546356.0
# ...              ...          ...     ...         ...         ...
# 1068  United Kingdom         2015  100.00    631452.0  65116219.0
# 1069  United Kingdom         2016  100.70    588993.0  65611593.0
# 1070  United Kingdom         2017  103.40    644209.0  66058859.0
# 1071  United Kingdom         2018  105.90    603953.0  66460344.0
# 1072  United Kingdom         2019  107.80    680906.0  66836327.0
#
#       Housing Index
# 21            76.80
# 22            81.60
# 23            87.57
# 24            92.10
# 25            95.33
# ...             ...
# 1068         100.00
# 1069         106.99
# 1070         111.86
# 1071         115.53
# 1072         116.67
#
# [452 rows x 6 columns]
